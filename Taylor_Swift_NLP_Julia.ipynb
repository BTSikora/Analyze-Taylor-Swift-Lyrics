# %% [markdown]
# # Analyze Taylor Swift Lyrics with Python
#
# ### Try some of these resources for extra help as you work:
#
# * [View the Analyze Taylor Swift Lyrics with Python Cheatsheet](https://www.codecademy.com/learn/case-study-analyze-taylor-swift-lyrics/modules/analyze-taylor-swift-lyrics/cheatsheet)
# * Learn more about analyzing text in [Apply Natural Language Processing with Python](https://www.codecademy.com/learn/paths/natural-language-processing)
#
# [View the solution notebook](./solution.html)
#
# [The original dataset was curated by Jan Llenzl Dagohoy and published on Kaggle](https://www.kaggle.com/datasets/thespacefreak/taylor-swift-song-lyrics-all-albums)

# %%
# %matplotlib inline

import pandas as pd
import string
import seaborn as sns
import matplotlib.pyplot as plt
import collections
import nltk
from nltk.tokenize import word_tokenize
from nltk.sentiment import SentimentIntensityAnalyzer

# %% [markdown]
# ### 1. Load the dataset
#
# After running the first cell to load all necessary libraries, we need to load our dataset.
# * Using pandas, load the dataset taylor_swift_lyrics_2006-2020_all.csv and save it as lyrics.
# * Inspect the first few rows.
# * Use `.info()` to determine how many rows there are, check for missing values, and check the variable types.

# %% [markdown]
# *Note that we added the lyrics from the new Midnights album. If you want to inspect the lyrics from that album, you can find them in the file tree. Click on the Jupyter logo in the upper left corner and you can see all the files.*
#
# *Use "taylor_swift_lyrics_2006-2022_all.csv" in the `pd.read_csv()` function below to also analyze Midnights.*

# %%
# load dataset
lyrics = pd.read_csv("taylor_swift_lyrics_2006-2020_all.csv")

#inspect the first few rows
lyrics.head(10)
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 5  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 6  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 7  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 8  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 9  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line
# 0                    There's something 'bout the way     1
# 1             The street looks when it's just rained     2
# 2  There's a glow off the pavement, you walk me t...     3
# 3  And you know I wanna ask you to dance right there     4
# 4             In the middle of the parking lot, yeah     5
# 5                                           Oh, yeah     6
# 6  We're driving down the road, I wonder if you know     7
# 7        I'm trying so hard not to get caught up now     8
# 8  But you're just so cool, run your hands throug...     9
# 9                 Absent-mindedly making me want you    10

# %%
#get info about the DataFrame
lyrics.info()

'''
8358 entries and no missing values, where we have an album name, track title, and lyrics. 
Line and track_n is an integer. 
'''
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8358 entries, 0 to 8357
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   album_name   8358 non-null   object
#  1   track_title  8358 non-null   object
#  2   track_n      8358 non-null   int64
#  3   lyric        8358 non-null   object
#  4   line         8358 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 326.6+ KB
# '\n8358 entries and no missing values, where we have an album name, track title, and lyrics. \nLine and track_n is an integer. \n'

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# The Taylor Swift lyrics dataset consists of comprehensive data on the lyrics from her albums 2020. There are no missing values. We can see the lyric details along the column axis and each lyric along the row axis. We can find the name  of each album, the track, and the line in which the lyric appears. We do not have year associated with this dataset.
#
# </details>

# %% [markdown]
# ### 2. Add essential data
#
# We know that we want to explore her use of terms over years, but this dataset doesn't have years. We can either merge a dataset or manually create a new column. We have created a function for you that fills in the year based on the album name.
#
# * Apply this function to the `lyrics` DataFrame to create a new column.
# * Inspect the first few rows of the DataFrame

# %%
# get a list of all the albums in this collection
## YOUR CODE HERE ##
albums = lyrics['album_name'].unique()
albums
# 'Taylor Swift','Fearless (Taylor’s Version)', 'Speak Now (Deluxe)', 'Red (Deluxe Edition)', '1989 (Deluxe)', 'reputation', 'Lover', 'evermore (deluxe version)', 'folklore (deluxe version)'
# Out:
# array(['Fearless (Taylor’s Version)', 'Red (Deluxe Edition)',
#        '1989 (Deluxe)', 'reputation', 'Taylor Swift',
#        'folklore (deluxe version)', 'Lover', 'evermore (deluxe version)',
#        'Speak Now (Deluxe)'], dtype=object)

# %%
# this is a function to map the name of the album to the year it was released
def album_release(row):  
    if row['album_name'] == 'Taylor Swift':
        return '2006'
    elif row['album_name'] == 'Fearless (Taylor’s Version)':
        return '2008'
    elif row['album_name'] == 'Speak Now (Deluxe)':
        return '2010'
    elif row['album_name'] == 'Red (Deluxe Edition)':
        return '2012'
    elif row['album_name'] == '1989 (Deluxe)':
        return '2014'
    elif row['album_name'] == 'reputation':
        return '2017'
    elif row['album_name'] == 'Lover':
        return '2019'
    elif row['album_name'] == 'evermore (deluxe version)':
        return '2020'
    #ok, we know folklore was actually released in Dec 2020, but this will make our analysis easier
    elif row['album_name'] == 'folklore (deluxe version)':
        return '2021'
    #this is slightly differently formatted because the album name is recorded two ways.
    elif 'midnights' in row['album_name']:
        return '2022'
    
    return 'No Date'


# apply the function to the album
## YOUR CODE HERE ##
lyrics['album_year'] = lyrics.apply(lambda row:album_release(row), axis = 1) # poczytaj o lambda

# inspect the first few rows of the DataFrame
## YOUR CODE HERE ##
lyrics.head(10)
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 5  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 6  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 7  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 8  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 9  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line album_year
# 0                    There's something 'bout the way     1       2008
# 1             The street looks when it's just rained     2       2008
# 2  There's a glow off the pavement, you walk me t...     3       2008
# 3  And you know I wanna ask you to dance right there     4       2008
# 4             In the middle of the parking lot, yeah     5       2008
# 5                                           Oh, yeah     6       2008
# 6  We're driving down the road, I wonder if you know     7       2008
# 7        I'm trying so hard not to get caught up now     8       2008
# 8  But you're just so cool, run your hands throug...     9       2008
# 9                 Absent-mindedly making me want you    10       2008

# %% [markdown]
# ### 3. Clean the lyric text
#
# To accurately count keyword mentions, we need to make everything lowercase everything, remove punctuation, and exclude stop words.
#
# * Change everything to lower case and save the result in a new column called `clean_lyric`.
# * Remove punctuation and save the result to the existing `clean_lyric` column.
# * Run the code we provided to remove stopwords.
# * Check to be sure you have what you expect by viewing the first few rows.

# %%
#lowercase
## YOUR CODE HERE ##
lyrics['clean_lyric'] = lyrics['lyric'].apply(lambda s:s.lower())

#remove punctuation
## YOUR CODE HERE ##
lyrics['clean_lyric'] = lyrics['clean_lyric'].str.replace('[^\w\s]', '') # punctuation in regexp '[^\w\s]'
lyrics
# Out:
#                        album_name                  track_title  track_n  \
# 0     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# ...                           ...                          ...      ...
# 8353           Speak Now (Deluxe)                     Superman       17
# 8354           Speak Now (Deluxe)                     Superman       17
# 8355           Speak Now (Deluxe)                     Superman       17
# 8356           Speak Now (Deluxe)                     Superman       17
# 8357           Speak Now (Deluxe)                     Superman       17
#
#                                                   lyric  line album_year  \
# 0                       There's something 'bout the way     1       2008
# 1                The street looks when it's just rained     2       2008
# 2     There's a glow off the pavement, you walk me t...     3       2008
# 3     And you know I wanna ask you to dance right there     4       2008
# 4                In the middle of the parking lot, yeah     5       2008
# ...                                                 ...   ...        ...
# 8353                   I'll be right here on the ground    51       2010
# 8354                            When you come back down    52       2010
# 8355                             La, la, la, la, la, la    53       2010
# 8356                             La, la, la, la, la, la    54       2010
# 8357                            When you come back down    55       2010
#
#                                             clean_lyric
# 0                         theres something bout the way
# 1                 the street looks when its just rained
# 2     theres a glow off the pavement you walk me to ...
# 3     and you know i wanna ask you to dance right there
# 4                 in the middle of the parking lot yeah
# ...                                                 ...
# 8353                    ill be right here on the ground
# 8354                            when you come back down
# 8355                                  la la la la la la
# 8356                                  la la la la la la
# 8357                            when you come back down
#
# [8358 rows x 7 columns]

# %%
#remove stopwords (see the next cell for illustration)
#create a small list of English stop words, feel free to edit this list
stop = ['the', 'a', 'this', 'that', 'to', 'is', 'am', 'was', 'were', 'be', 'being', 'been', 'i', 'me', 'your', 'our', 'few',
       'before', 'she', 'her', 'him', 's', 'hers', 'his']

#there are three steps in one here - explained below
#we make a list of words with `.split()`
#then we remove all the words in our list
#then we join the words back together into a string
lyrics['clean_lyric'] = lyrics['clean_lyric'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# %%
# inspect the first few rows of the DataFrame
## YOUR CODE HERE ##
lyrics.head(10)
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 5  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 6  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 7  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 8  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 9  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line album_year  \
# 0                    There's something 'bout the way     1       2008
# 1             The street looks when it's just rained     2       2008
# 2  There's a glow off the pavement, you walk me t...     3       2008
# 3  And you know I wanna ask you to dance right there     4       2008
# 4             In the middle of the parking lot, yeah     5       2008
# 5                                           Oh, yeah     6       2008
# 6  We're driving down the road, I wonder if you know     7       2008
# 7        I'm trying so hard not to get caught up now     8       2008
# 8  But you're just so cool, run your hands throug...     9       2008
# 9                 Absent-mindedly making me want you    10       2008
#
#                                      clean_lyric
# 0                      theres something bout way
# 1              street looks when its just rained
# 2          theres glow off pavement you walk car
# 3   and you know wanna ask you dance right there
# 4                  in middle of parking lot yeah
# 5                                        oh yeah
# 6           driving down road wonder if you know
# 7        im trying so hard not get caught up now
# 8  but youre just so cool run hands through hair
# 9                 absentmindedly making want you

# %% [markdown]
# ### The next 4 cells are for illustration only

# %%
#see what `.split()` does
lyrics['clean_lyric_list'] = lyrics['clean_lyric'].apply(lambda x: x.split())
print(lyrics.head())
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line album_year  \
# 0                    There's something 'bout the way     1       2008
# 1             The street looks when it's just rained     2       2008
# 2  There's a glow off the pavement, you walk me t...     3       2008
# 3  And you know I wanna ask you to dance right there     4       2008
# 4             In the middle of the parking lot, yeah     5       2008
#
#                                     clean_lyric  \
# 0                     theres something bout way
# 1             street looks when its just rained
# 2         theres glow off pavement you walk car
# 3  and you know wanna ask you dance right there
# 4                 in middle of parking lot yeah
#
#                                     clean_lyric_list
# 0                     [theres, something, bout, way]
# 1           [street, looks, when, its, just, rained]
# 2      [theres, glow, off, pavement, you, walk, car]
# 3  [and, you, know, wanna, ask, you, dance, right...
# 4               [in, middle, of, parking, lot, yeah]

# %%
#see what `.join()` does
lyrics['clean_lyric_list_rejoined'] = lyrics['clean_lyric_list'].apply(lambda x: ' '.join(x))
print(lyrics.head())
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line album_year  \
# 0                    There's something 'bout the way     1       2008
# 1             The street looks when it's just rained     2       2008
# 2  There's a glow off the pavement, you walk me t...     3       2008
# 3  And you know I wanna ask you to dance right there     4       2008
# 4             In the middle of the parking lot, yeah     5       2008
#
#                                     clean_lyric  \
# 0                     theres something bout way
# 1             street looks when its just rained
# 2         theres glow off pavement you walk car
# 3  and you know wanna ask you dance right there
# 4                 in middle of parking lot yeah
#
#                                     clean_lyric_list  \
# 0                     [theres, something, bout, way]
# 1           [street, looks, when, its, just, rained]
# 2      [theres, glow, off, pavement, you, walk, car]
# 3  [and, you, know, wanna, ask, you, dance, right...
# 4               [in, middle, of, parking, lot, yeah]
#
#                       clean_lyric_list_rejoined
# 0                     theres something bout way
# 1             street looks when its just rained
# 2         theres glow off pavement you walk car
# 3  and you know wanna ask you dance right there
# 4                 in middle of parking lot yeah

# %%
#remove those illustration columns
lyrics.drop(['clean_lyric_list', 'clean_lyric_list_rejoined'], axis=1, inplace=True)
print(lyrics.head())
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line album_year  \
# 0                    There's something 'bout the way     1       2008
# 1             The street looks when it's just rained     2       2008
# 2  There's a glow off the pavement, you walk me t...     3       2008
# 3  And you know I wanna ask you to dance right there     4       2008
# 4             In the middle of the parking lot, yeah     5       2008
#
#                                     clean_lyric
# 0                     theres something bout way
# 1             street looks when its just rained
# 2         theres glow off pavement you walk car
# 3  and you know wanna ask you dance right there
# 4                 in middle of parking lot yeah

# %%
#there are many pre-built lists of stopwords, including one from sklearn.
#Most exclude too many words to be appropriate for song lyric analysis.
from sklearn.feature_extraction import text
skl_stop = text.ENGLISH_STOP_WORDS
print(skl_stop)
# Out:
# frozenset({'am', 'who', 'were', 'have', 'about', 'what', 'cant', 'whoever', 'around', 'how', 'inc', 'much', 'myself', 'me', 'beside', 'sometime', 'therefore', 'thence', 'those', 'my', 'here', 'him', 'thin', 'or', 'same', 'among', 'to', 'some', 'wherever', 'together', 'towards', 'every', 'off', 'also', 'down', 'fill', 'anything', 'nowhere', 'himself', 're', 'co', 'never', 'with', 'many', 'otherwise', 'against', 'twenty', 'throughout', 'five', 'though', 'will', 'something', 'most', 'over', 'whatever', 'find', 'thereafter', 'seemed', 'anyone', 'own', 'still', 'anyhow', 'for', 'a', 'alone', 'itself', 'above', 'please', 'become', 'con', 'full', 'whereupon', 'meanwhile', 'why', 'he', 'should', 'next', 'amount', 'could', 'neither', 'often', 'etc', 'ten', 'fifteen', 'hereby', 'may', 'until', 'very', 'while', 'few', 'name', 'show', 'although', 'if', 'into', 'else', 'it', 'too', 'across', 'these', 'done', 'empty', 'former', 'whose', 'becoming', 'such', 'several', 'thru', 'its', 'do', 'get', 'be', 'system', 'thereupon', 'each', 'once', 'eg', 'top', 'onto', 'front', 'hereafter', 'someone', 'well', 'are', 'toward', 'nine', 'ours', 'below', 'mostly', 'under', 'afterwards', 'fifty', 'first', 'within', 'your', 'both', 'is', 'sincere', 'nobody', 'another', 'besides', 'found', 'however', 'without', 'due', 'only', 'amoungst', 'before', 'she', 'hence', 'other', 'than', 'last', 'again', 'we', 'eight', 'which', 'all', 'being', 'herself', 'along', 'go', 'take', 'on', 'except', 'noone', 'yourself', 'our', 'can', 'more', 'but', 'upon', 'because', 'sometimes', 'indeed', 'had', 'call', 'whither', 'was', 'formerly', 'seeming', 'hers', 'cannot', 'somewhere', 'wherein', 'nothing', 'three', 'becomes', 'during', 'already', 'out', 'bill', 'yours', 'interest', 'nor', 'the', 'anyway', 'none', 'after', 'whence', 'whole', 'themselves', 'ever', 'forty', 'one', 'anywhere', 'nevertheless', 'amongst', 'not', 'keep', 'cry', 'ie', 'side', 'between', 'would', 'sixty', 'further', 'you', 'either', 'namely', 'from', 'must', 'hereupon', 'third', 'has', 'in', 'via', 'whereas', 'see', 'fire', 'an', 'thus', 'move', 'less', 'part', 'up', 'hasnt', 'so', 'per', 'everything', 'twelve', 'bottom', 'seems', 'where', 'made', 'everyone', 'i', 'thick', 'mill', 'them', 'us', 'therein', 'six', 'least', 'there', 'yourselves', 'his', 'her', 'latterly', 'then', 'un', 'even', 'put', 'of', 'beforehand', 'two', 'since', 'now', 'rather', 'whether', 'beyond', 'somehow', 'as', 'herein', 'always', 'no', 'their', 'whenever', 'moreover', 'this', 'hundred', 'ourselves', 'back', 'de', 'thereby', 'behind', 'elsewhere', 'describe', 'everywhere', 'at', 'might', 'detail', 'couldnt', 'mine', 'yet', 'eleven', 'whom', 'they', 'latter', 'became', 'that', 'when', 'others', 'and', 'almost', 'through', 'serious', 'enough', 'four', 'give', 'ltd', 'been', 'any', 'by', 'perhaps', 'whereafter', 'whereby', 'seem'})

# %% [markdown]
# ### 4. Find keyword mentions
#
# Because we are most interested in "midnight", we will first count how many times midnight occurs in Taylor Swift's lyrics.
#
# * Create a new column to indicate if a lyric has "midnight" in it.
# * Check how many times midnight occurrs

# %%
#create a new column to reflect if the lyrics contain midnight
## YOUR CODE HERE ## 
lyrics['midnight'] = lyrics['clean_lyric'].str.contains('midnight')
sum(lyrics['midnight'])
# Out:
# 9

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# Midnight is not very common -- it only appeared 9 times!
#
# </details>

# %% [markdown]
# ### 5. Expand the keyword list
#
# Midnight might not be the only way that Taylor Swift has talked about night. We need to expand our list. We've made a list of night words and day words. Feel free to add or remove words to make the list your own.
#
# * Join the lists into a regular expression string using the `.join()` function and the `|` to indicate "or"
# * Create a new column for each word category (day, night, time) that evaluates the clean lyrics for the presence of the words in your regular expression.
# * Count how many times the words appeared and print the result to the screen
# * Inspect the first few rows of the lyrics DataFrame to be sure it looks as you expect

# %%
#night, day, and other time-related words
night = ['night','nights','midnight','midnights','dawn', 'dusk', 'evening', 'evenings', 'late', 'dark', '1am', '2am', '3am', '4am', 'moonlight','sunset']
day = ['day','days', 'morning','morning', 'light', 'lights', 'sun', 'dawn', 'noon', 'golden', 'bright','sunrise','sunrises']
time = ['today', 'tomorrow', 'yesterday']

# %%
#create a regular expression string for each list of words
## YOUR CODE HERE ##
night_re = '|'.join(night) # to create 
day_re = '|'.join(day)
time_re = '|'.join(time)

#create a new column for each category of words
## YOUR CODE HERE ##
# lyrics['midnight'] = lyrics['clean_lyric'].str.contains('midnight')

lyrics['night_words'] = lyrics['clean_lyric'].str.contains(night_re)
lyrics['day_words'] = lyrics['clean_lyric'].str.contains(day_re)
lyrics['time_words'] = lyrics['clean_lyric'].str.contains(time_re)

#count the number of times each category of word appears in the lyrics
## YOUR CODE HERE ##

#print the count of each word category
## YOUR CODE HERE ##

# print(f'{sum(lyrics['night_words'])}, {sum(lyrics['day_words'])},  {sum(lyrics['time_words'])}')
sum(lyrics['night_words']) 
sum(lyrics['day_words'])
sum(lyrics['time_words'])
# Out:
# 35

# %%
#inspect the first few rows
## YOUR CODE HERE ##
lyrics
# Out:
#                        album_name                  track_title  track_n  \
# 0     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# ...                           ...                          ...      ...
# 8353           Speak Now (Deluxe)                     Superman       17
# 8354           Speak Now (Deluxe)                     Superman       17
# 8355           Speak Now (Deluxe)                     Superman       17
# 8356           Speak Now (Deluxe)                     Superman       17
# 8357           Speak Now (Deluxe)                     Superman       17
#
#                                                   lyric  line album_year  \
# 0                       There's something 'bout the way     1       2008
# 1                The street looks when it's just rained     2       2008
# 2     There's a glow off the pavement, you walk me t...     3       2008
# 3     And you know I wanna ask you to dance right there     4       2008
# 4                In the middle of the parking lot, yeah     5       2008
# ...                                                 ...   ...        ...
# 8353                   I'll be right here on the ground    51       2010
# 8354                            When you come back down    52       2010
# 8355                             La, la, la, la, la, la    53       2010
# 8356                             La, la, la, la, la, la    54       2010
# 8357                            When you come back down    55       2010
#
#                                        clean_lyric  midnight  night_words  \
# 0                        theres something bout way     False        False
# 1                street looks when its just rained     False        False
# 2            theres glow off pavement you walk car     False        False
# 3     and you know wanna ask you dance right there     False        False
# 4                    in middle of parking lot yeah     False        False
# ...                                            ...       ...          ...
# 8353                      ill right here on ground     False        False
# 8354                       when you come back down     False        False
# 8355                             la la la la la la     False        False
# 8356                             la la la la la la     False        False
# 8357                       when you come back down     False        False
#
#       day_words  time_words
# 0         False       False
# 1         False       False
# 2         False       False
# 3         False       False
# 4         False       False
# ...         ...         ...
# 8353      False       False
# 8354      False       False
# 8355      False       False
# 8356      False       False
# 8357      False       False
#
# [8358 rows x 11 columns]

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# Taylor Swift has referenced time alot, there's enough mentions for us to potentially spot some trends. Also, she has mentioned day far more than night. This might be because of the search terms, so we might consider revisiting the list. Or it could be because she is actually more focused on day and light than she is on night and dark.
#
# </details>

# %% [markdown]
# # Task Group 2

# %% [markdown]
# ### 6. Visualize how Taylor Swift's mentions of time have changed over time.
#
# Now that we know that she has referenced time, we can see if that has changed, and if she has been dropping any hints about her upcoming album.
# * Create a new dataframe called `yearly_mentions` that groups her mentions by year, and takes the sum of the other columns. Reset the index on this DataFrame to make it easier to use with matplotlib
# * Create a line chart in matplotlib showing the night mentions over time.

# %%
#create a new dataframe for yearly mentions that groups mentions by year 
## YOUR CODE HERE ## 
'''
basically it says: copy lyrics DF and group it by album_year and 
takes the sum of the rest of the remaining columns and reset index
'''
yearly_mentions = lyrics
yearly_mentions = yearly_mentions.groupby('album_year').sum().reset_index()

# %%
#plot the mentions of night over years
## YOUR CODE HERE ##
yearly_mentions.plot(x = 'album_year', y =['midnight','night_words','day_words','time_words'])
# Out:
# <AxesSubplot:xlabel='album_year'>

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# It looks like there was a peak in her mentioning night around 2012. It seems like those mentions have become less prevalent over time, with an actual dip in 2019! We had expected midnight to appear more often around then, based on rumors that she plans everything 3 years out.
#
# </details>

# %% [markdown]
# ### 7. What albums are the most night/day focused?
# Now that we have a table of counts, it's very easy to figure out which albums have the most mentions of day or night. But our DataFrame only has the years, not the album names. We need to add those back in.
# * Run the code that reinstates the album name for this dataframe.
# * Use `.sort_values()` to order the yearly_mentions table and find which year has the most mentions of night.
# * Sort the day column as well.

# %%
#reinstate the album name
#read the album_year_name.csv
year_name = pd.read_csv('album_year_name.csv')

#sort both dataframes by year
yearly_mentions.sort_values(by='album_year', ascending=True, inplace=True, ignore_index=True)
year_name.sort_values(by='album_year', ascending=True, inplace=True, ignore_index=True)

#add the new column for album name
yearly_mentions['album_name'] = year_name['album_name']
yearly_mentions
# Out:
#   album_year  track_n   line  midnight  night_words  day_words  time_words  \
# 0       2006     4867  13456         0           19         25           3
# 1       2008    15644  27793         0           42         65          20
# 2       2010     8450  27489         0           31         53           4
# 3       2012    11992  27800         1           48         53           7
# 4       2014     8424  33546         2           31         41           0
# 5       2017     7640  33775         3           26         25           0
# 6       2019     8813  25741         0           22         46           0
# 7       2020     8443  25712         2           18         38           0
# 8       2021     6193  16854         1            8         17           1
#
#                     album_name
# 0                 Taylor Swift
# 1  Fearless (Taylor’s Version)
# 2           Speak Now (Deluxe)
# 3         Red (Deluxe Edition)
# 4                1989 (Deluxe)
# 5                   reputation
# 6                        Lover
# 7    evermore (deluxe version)
# 8    folklore (deluxe version)

# %%
#sort the lyrics by the night column to find the albums with the most night references
## YOUR CODE HERE ##
yearly_mentions.sort_values(by='night_words', ascending=False, inplace=True)
yearly_mentions
# Out:
#   album_year  track_n   line  midnight  night_words  day_words  time_words  \
# 3       2012    11992  27800         1           48         53           7
# 1       2008    15644  27793         0           42         65          20
# 2       2010     8450  27489         0           31         53           4
# 4       2014     8424  33546         2           31         41           0
# 5       2017     7640  33775         3           26         25           0
# 6       2019     8813  25741         0           22         46           0
# 0       2006     4867  13456         0           19         25           3
# 7       2020     8443  25712         2           18         38           0
# 8       2021     6193  16854         1            8         17           1
#
#                     album_name
# 3         Red (Deluxe Edition)
# 1  Fearless (Taylor’s Version)
# 2           Speak Now (Deluxe)
# 4                1989 (Deluxe)
# 5                   reputation
# 6                        Lover
# 0                 Taylor Swift
# 7    evermore (deluxe version)
# 8    folklore (deluxe version)

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# Her most "nightly" album was reputation in 2012, whereas her least nightly album was also the one right before Midnight. Has she been saving all her night-related lyrics for the past 3 years?
#
# </details>

# %%
#sort the lyrics by the day column to find the albums with the most day references
## YOUR CODE HERE ##
yearly_mentions.sort_values(by='day_words', ascending=False, inplace=True)
yearly_mentions
# Out:
#   album_year  track_n   line  midnight  night_words  day_words  time_words  \
# 1       2008    15644  27793         0           42         65          20
# 3       2012    11992  27800         1           48         53           7
# 2       2010     8450  27489         0           31         53           4
# 6       2019     8813  25741         0           22         46           0
# 4       2014     8424  33546         2           31         41           0
# 7       2020     8443  25712         2           18         38           0
# 5       2017     7640  33775         3           26         25           0
# 0       2006     4867  13456         0           19         25           3
# 8       2021     6193  16854         1            8         17           1
#
#                     album_name
# 1  Fearless (Taylor’s Version)
# 3         Red (Deluxe Edition)
# 2           Speak Now (Deluxe)
# 6                        Lover
# 4                1989 (Deluxe)
# 7    evermore (deluxe version)
# 5                   reputation
# 0                 Taylor Swift
# 8    folklore (deluxe version)

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# It seems like her older work focused on day much more than her more recent. There was a period of time (2008-2012) when she was really focused on day, but it seems to have become less central to her work more recently.
#
# </details>

# %% [markdown]
# ### 8. Compare day to night mentions
# * Create another line chart with both the night mentions and the day mentions

# %%
#create a plot with one line showing number of night references by year 
#and another line with the number of day references by year
## YOUR CODE HERE ##
yearly_mentions.sort_values(by='album_year', ascending=True, inplace=True)
yearly_mentions.plot(x = 'album_year', y = ['night_words', 'day_words'])
# Out:
# <AxesSubplot:xlabel='album_year'>

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# Well this is interesting. We see a similar dip in referencing time around 2017, but a sharp increase in both 2019 and 2020 to reference day.
#
# </details>

# %% [markdown]
# ### 9. Investigate position of day vs. night mentions within albums
# Maybe her references to time aren't always about the year that she released the album, but the ebb and flow of the album itself. Let's plot where, within each album, references to day and night occur.
#
# * Create a variable that indicates the position of a lyric within an album. Call this 'position'.
# * Create a new dataframe called positional_mentions that groups her mentions by album position, and takes the sum of the other columns. Reset the index on this DataFrame to make it easier to use with matplotlib.
# * Create a line chart in matplotlib showing the night and day mentions as a position within the album.
#
# *Remember that you can always print the head of the DataFrame to check your work*

# %%
#create a position variable that includes both the track number and line number
## YOUR CODE HERE ##
lyrics['position'] = lyrics['track_n'] + (lyrics['line']/1000)
lyrics

#create a new DataFrame that is grouped by position
## YOUR CODE HERE ##
positional_mentions = lyrics.groupby('position').sum().reset_index()
positional_mentions
# Out:
#       position  track_n  line  midnight  night_words  day_words  time_words
# 0        1.001        9     9         0            1          2           0
# 1        1.002        9    18         0            1          0           0
# 2        1.003        9    27         0            0          1           0
# 3        1.004        9    36         0            1          1           0
# 4        1.005        9    45         0            0          1           0
# ...        ...      ...   ...       ...          ...        ...         ...
# 1626    26.041       26    41         0            0          0           0
# 1627    26.042       26    42         0            0          0           0
# 1628    26.043       26    43         0            0          0           0
# 1629    26.044       26    44         0            0          0           0
# 1630    26.045       26    45         0            0          0           0
#
# [1631 rows x 7 columns]

# %%
#increase the size of the plot 
fig = plt.gcf()
fig.set_size_inches(25,10)

#create a plot with two lines to show frequency of day vs. night references by position in the album
## YOUR CODE HERE ##
plt.plot(positional_mentions['position'], positional_mentions['night_words'], label = 'night')
plt.plot(positional_mentions['position'], positional_mentions['day_words'], label = 'day')
plt.legend()

plt.show()

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
#     Honestly not that much -- we can't see any strong trends here. Best to move on.
# </details>

# %% [markdown]
# # Task Group 3

# %% [markdown]
# ### 10. Tokenize the Lyrics
# It's great to know how much she has focused on day and night, but we would also like to do a little more sophisticated analysis. Before we can work with our cleaned lyrics, we will have to tokenize them. Tokenization is a special way of breaking up words that is a little more nuanced than just using white space. The output is a list of words that we can then perform text analysis on.
#
# We will use the `word_tokenize` function from NLTK (the Natural Language ToolKit), and apply it to every row in our DataFrame with a lambda expression.
#
# * Run the cell to tokenize the cleaned lyrics.
# * Inspect the first few rows of the lyrics DataFrame
# * Create a list of all the tokens in the lyrics_tok column into one list
# * Use the Counter function from the collections package to count the number of times each word appears
# * Sort the resulting dictionary

# %%
#run this cell to tokenize the words in the clean_lyric column
lyrics['lyrics_tok'] = lyrics['clean_lyric'].apply(lambda x: word_tokenize(x))

# %%
import nltk
nltk.download('punkt')

#run this cell to tokenize the words in the clean_lyric column
lyrics['lyrics_tok'] = lyrics['clean_lyric'].apply(lambda x: word_tokenize(x))
# Out:
# [nltk_data] Downloading package punkt to /home/ccuser/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
#inspect the first few lines
## YOUR CODE HERE ##
lyrics
# Out:
#                        album_name                  track_title  track_n  \
# 0     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# ...                           ...                          ...      ...
# 8353           Speak Now (Deluxe)                     Superman       17
# 8354           Speak Now (Deluxe)                     Superman       17
# 8355           Speak Now (Deluxe)                     Superman       17
# 8356           Speak Now (Deluxe)                     Superman       17
# 8357           Speak Now (Deluxe)                     Superman       17
#
#                                                   lyric  line album_year  \
# 0                       There's something 'bout the way     1       2008
# 1                The street looks when it's just rained     2       2008
# 2     There's a glow off the pavement, you walk me t...     3       2008
# 3     And you know I wanna ask you to dance right there     4       2008
# 4                In the middle of the parking lot, yeah     5       2008
# ...                                                 ...   ...        ...
# 8353                   I'll be right here on the ground    51       2010
# 8354                            When you come back down    52       2010
# 8355                             La, la, la, la, la, la    53       2010
# 8356                             La, la, la, la, la, la    54       2010
# 8357                            When you come back down    55       2010
#
#                                        clean_lyric  midnight  night_words  \
# 0                        theres something bout way     False        False
# 1                street looks when its just rained     False        False
# 2            theres glow off pavement you walk car     False        False
# 3     and you know wanna ask you dance right there     False        False
# 4                    in middle of parking lot yeah     False        False
# ...                                            ...       ...          ...
# 8353                      ill right here on ground     False        False
# 8354                       when you come back down     False        False
# 8355                             la la la la la la     False        False
# 8356                             la la la la la la     False        False
# 8357                       when you come back down     False        False
#
#       day_words  time_words  position  \
# 0         False       False     1.001
# 1         False       False     1.002
# 2         False       False     1.003
# 3         False       False     1.004
# 4         False       False     1.005
# ...         ...         ...       ...
# 8353      False       False    17.051
# 8354      False       False    17.052
# 8355      False       False    17.053
# 8356      False       False    17.054
# 8357      False       False    17.055
#
#                                              lyrics_tok
# 0                        [theres, something, bout, way]
# 1              [street, looks, when, its, just, rained]
# 2         [theres, glow, off, pavement, you, walk, car]
# 3     [and, you, know, wan, na, ask, you, dance, rig...
# 4                  [in, middle, of, parking, lot, yeah]
# ...                                                 ...
# 8353                     [ill, right, here, on, ground]
# 8354                      [when, you, come, back, down]
# 8355                           [la, la, la, la, la, la]
# 8356                           [la, la, la, la, la, la]
# 8357                      [when, you, come, back, down]
#
# [8358 rows x 13 columns]

# %%
#determine what words overall are the most frequently used words
import numpy as np
#create a list of all the words in the lyrics_tok column
word_list = [word for list_ in lyrics['lyrics_tok'] for word in list_]
word_list
#use the counter function to count the number of times each word appears
## YOUR CODE HERE ##
words = pd.value_counts(np.array(word_list))
words

#sort the word frequencies to find out the most common words she's used. 
## YOUR CODE HERE ##

#call the word frequency
## YOUR CODE HERE ##
# Out:
# you           2835
# and           1712
# it             931
# in             887
# my             816
#               ...
# politics         1
# sensual          1
# sequin           1
# outskirts        1
# lovestruck       1
# Length: 3485, dtype: int64

# %%
#use the counter function to count the number of times each word appears
word_frequency = collections.Counter(word_list)
#sort the word frequencies to find out the most common words she's used. 
word_frequency = sorted(word_frequency.items(), key=lambda x: x[1], reverse=True)
#call the word frequency
word_frequency
# Out:
# [('you', 2835),
#  ('and', 1712),
#  ('it', 931),
#  ('in', 887),
#  ('my', 816),
#  ('of', 592),
#  ('but', 540),
#  ('all', 531),
#  ('im', 501),
#  ('we', 498),
#  ('like', 488),
#  ('on', 467),
#  ('know', 456),
#  ('so', 422),
#  ('oh', 411),
#  ('dont', 406),
#  ('when', 392),
#  ('its', 380),
#  ('never', 353),
#  ('youre', 343),
#  ('just', 339),
#  ('for', 306),
#  ('now', 305),
#  ('with', 302),
#  ('love', 295),
#  ('what', 284),
#  ('na', 276),
#  ('up', 272),
#  ('out', 270),
#  ('back', 267),
#  ('time', 261),
#  ('cause', 253),
#  ('at', 249),
#  ('if', 245),
#  ('are', 225),
#  ('got', 221),
#  ('no', 213),
#  ('one', 201),
#  ('see', 199),
#  ('say', 198),
#  ('do', 195),
#  ('think', 192),
#  ('baby', 188),
#  ('down', 181),
#  ('want', 181),
#  ('go', 181),
#  ('they', 173),
#  ('come', 172),
#  ('could', 167),
#  ('can', 164),
#  ('there', 162),
#  ('not', 162),
#  ('wan', 161),
#  ('cant', 157),
#  ('ill', 156),
#  ('right', 155),
#  ('said', 146),
#  ('have', 146),
#  ('yeah', 145),
#  ('he', 144),
#  ('ever', 140),
#  ('would', 140),
#  ('had', 134),
#  ('look', 133),
#  ('thats', 133),
#  ('get', 127),
#  ('how', 122),
#  ('stay', 122),
#  ('here', 121),
#  ('take', 119),
#  ('id', 119),
#  ('way', 117),
#  ('ive', 116),
#  ('tell', 115),
#  ('night', 114),
#  ('gon', 113),
#  ('still', 113),
#  ('about', 112),
#  ('home', 110),
#  ('as', 108),
#  ('off', 104),
#  ('did', 102),
#  ('made', 102),
#  ('good', 102),
#  ('ooh', 101),
#  ('why', 100),
#  ('from', 98),
#  ('too', 98),
#  ('ohoh', 97),
#  ('feel', 96),
#  ('around', 95),
#  ('everything', 93),
#  ('bad', 93),
#  ('better', 90),
#  ('then', 90),
#  ('things', 90),
#  ('didnt', 89),
#  ('away', 88),
#  ('only', 86),
#  ('call', 85),
#  ('through', 84),
#  ('wish', 84),
#  ('girl', 84),
#  ('again', 84),
#  ('new', 83),
#  ('eyes', 82),
#  ('shake', 81),
#  ('let', 81),
#  ('long', 81),
#  ('knew', 79),
#  ('every', 79),
#  ('who', 76),
#  ('red', 76),
#  ('first', 75),
#  ('ah', 75),
#  ('well', 74),
#  ('will', 74),
#  ('youll', 73),
#  ('name', 73),
#  ('eh', 73),
#  ('last', 72),
#  ('yet', 71),
#  ('little', 70),
#  ('make', 70),
#  ('by', 70),
#  ('thing', 70),
#  ('nothing', 68),
#  ('forever', 67),
#  ('where', 66),
#  ('hes', 65),
#  ('life', 64),
#  ('hey', 64),
#  ('best', 63),
#  ('keep', 62),
#  ('us', 62),
#  ('break', 62),
#  ('face', 61),
#  ('or', 61),
#  ('leave', 61),
#  ('heart', 61),
#  ('day', 60),
#  ('lights', 60),
#  ('alone', 59),
#  ('even', 59),
#  ('mind', 58),
#  ('always', 58),
#  ('gone', 58),
#  ('need', 57),
#  ('theres', 56),
#  ('remember', 56),
#  ('waiting', 55),
#  ('into', 55),
#  ('something', 54),
#  ('should', 54),
#  ('smile', 54),
#  ('man', 54),
#  ('thought', 52),
#  ('beautiful', 52),
#  ('over', 52),
#  ('car', 51),
#  ('isnt', 51),
#  ('dancing', 51),
#  ('knows', 50),
#  ('aint', 49),
#  ('some', 49),
#  ('whoa', 49),
#  ('hands', 48),
#  ('friends', 48),
#  ('find', 48),
#  ('an', 48),
#  ('hope', 48),
#  ('wont', 48),
#  ('mad', 48),
#  ('mine', 47),
#  ('hold', 47),
#  ('head', 46),
#  ('walk', 45),
#  ('fall', 45),
#  ('lost', 45),
#  ('shes', 45),
#  ('door', 45),
#  ('end', 45),
#  ('wrong', 45),
#  ('run', 44),
#  ('hand', 44),
#  ('put', 44),
#  ('coming', 44),
#  ('feeling', 44),
#  ('mean', 44),
#  ('hate', 44),
#  ('left', 43),
#  ('once', 43),
#  ('sorry', 42),
#  ('clear', 42),
#  ('light', 41),
#  ('miss', 41),
#  ('much', 41),
#  ('place', 41),
#  ('trying', 40),
#  ('them', 40),
#  ('talk', 40),
#  ('youve', 40),
#  ('old', 40),
#  ('daylight', 40),
#  ('than', 39),
#  ('enough', 39),
#  ('room', 39),
#  ('saw', 39),
#  ('took', 39),
#  ('dress', 38),
#  ('dreams', 38),
#  ('hear', 38),
#  ('watch', 38),
#  ('follow', 38),
#  ('york', 38),
#  ('meet', 38),
#  ('everybody', 38),
#  ('woods', 38),
#  ('town', 37),
#  ('really', 37),
#  ('whole', 37),
#  ('play', 37),
#  ('dark', 37),
#  ('met', 36),
#  ('rain', 36),
#  ('world', 36),
#  ('these', 36),
#  ('live', 36),
#  ('street', 35),
#  ('kiss', 35),
#  ('give', 35),
#  ('known', 35),
#  ('their', 35),
#  ('ha', 35),
#  ('other', 34),
#  ('people', 34),
#  ('together', 34),
#  ('goes', 34),
#  ('blue', 34),
#  ('gave', 33),
#  ('forget', 33),
#  ('big', 33),
#  ('asking', 33),
#  ('nice', 33),
#  ('shouldve', 33),
#  ('more', 32),
#  ('song', 32),
#  ('has', 32),
#  ('used', 32),
#  ('welcome', 32),
#  ('trouble', 32),
#  ('darling', 32),
#  ('wanted', 31),
#  ('anything', 31),
#  ('yes', 31),
#  ('same', 31),
#  ('fight', 31),
#  ('phone', 31),
#  ('youd', 31),
#  ('game', 31),
#  ('lose', 31),
#  ('those', 30),
#  ('else', 30),
#  ('loved', 30),
#  ('wait', 30),
#  ('getting', 30),
#  ('another', 30),
#  ('meaning', 30),
#  ('hard', 29),
#  ('please', 29),
#  ('help', 29),
#  ('myself', 29),
#  ('silence', 29),
#  ('today', 29),
#  ('turn', 29),
#  ('touch', 29),
#  ('official', 29),
#  ('lyrics', 29),
#  ('verified', 29),
#  ('late', 28),
#  ('side', 28),
#  ('heard', 28),
#  ('times', 28),
#  ('mr', 28),
#  ('drive', 27),
#  ('believe', 27),
#  ('soon', 27),
#  ('found', 27),
#  ('went', 27),
#  ('looking', 27),
#  ('without', 27),
#  ('breathe', 27),
#  ('show', 27),
#  ('wed', 27),
#  ('fly', 27),
#  ('true', 27),
#  ('fake', 27),
#  ('soul', 27),
#  ('body', 27),
#  ('til', 26),
#  ('try', 26),
#  ('might', 26),
#  ('standing', 26),
#  ('change', 26),
#  ('high', 26),
#  ('honey', 26),
#  ('weve', 26),
#  ('bye', 26),
#  ('joeboy', 26),
#  ('sip', 26),
#  ('alcohol', 26),
#  ('someday', 25),
#  ('story', 25),
#  ('dead', 25),
#  ('save', 25),
#  ('fine', 25),
#  ('friend', 25),
#  ('rains', 25),
#  ('came', 25),
#  ('places', 25),
#  ('grow', 25),
#  ('seen', 24),
#  ('years', 24),
#  ('boy', 24),
#  ('after', 24),
#  ('far', 24),
#  ('front', 24),
#  ('fun', 24),
#  ('dance', 23),
#  ('makes', 23),
#  ('ground', 23),
#  ('shine', 23),
#  ('many', 23),
#  ('happy', 23),
#  ('anymore', 23),
#  ('couldnt', 23),
#  ('crazy', 23),
#  ('eye', 23),
#  ('jump', 23),
#  ('dream', 23),
#  ('alright', 23),
#  ('wishing', 23),
#  ('cool', 22),
#  ('summer', 22),
#  ('since', 22),
#  ('sometimes', 22),
#  ('sad', 22),
#  ('okay', 22),
#  ('must', 22),
#  ('guess', 22),
#  ('lips', 22),
#  ('starlight', 22),
#  ('stop', 22),
#  ('getaway', 22),
#  ('looks', 21),
#  ('very', 21),
#  ('both', 21),
#  ('young', 21),
#  ('window', 21),
#  ('thinking', 21),
#  ('wouldve', 21),
#  ('past', 21),
#  ('picture', 21),
#  ('burning', 21),
#  ('tied', 21),
#  ('moment', 20),
#  ('somebody', 20),
#  ('walked', 20),
#  ('nobody', 20),
#  ('days', 20),
#  ('walking', 20),
#  ('house', 20),
#  ('stand', 20),
#  ('morning', 20),
#  ('words', 20),
#  ('games', 20),
#  ('em', 20),
#  ('pain', 20),
#  ('ta', 20),
#  ('theyll', 20),
#  ('died', 20),
#  ('bout', 19),
#  ('middle', 19),
#  ('road', 19),
#  ('hair', 19),
#  ('close', 19),
#  ('cold', 19),
#  ('fairytale', 19),
#  ('maybe', 19),
#  ('kind', 19),
#  ('clean', 19),
#  ('told', 19),
#  ('perfectly', 19),
#  ('babe', 19),
#  ('showed', 19),
#  ('blood', 19),
#  ('wonderland', 19),
#  ('ask', 18),
#  ('making', 18),
#  ('gets', 18),
#  ('deep', 18),
#  ('girls', 18),
#  ('real', 18),
#  ('tonight', 18),
#  ('laughing', 18),
#  ('single', 18),
#  ('god', 18),
#  ('finally', 18),
#  ('loving', 18),
#  ('missing', 18),
#  ('yours', 18),
#  ('stood', 17),
#  ('while', 17),
#  ('magic', 17),
#  ('perfect', 17),
#  ('doesnt', 17),
#  ('along', 17),
#  ('easy', 17),
#  ('cut', 17),
#  ('sky', 17),
#  ('pretty', 17),
#  ('because', 17),
#  ('fell', 17),
#  ('stars', 17),
#  ('shame', 17),
#  ('two', 17),
#  ('felt', 17),
#  ('bet', 17),
#  ('read', 17),
#  ('lucky', 17),
#  ('burn', 17),
#  ('begin', 17),
#  ('delicate', 17),
#  ('string', 17),
#  ('la', 17),
#  ('caught', 16),
#  ('begging', 16),
#  ('tired', 16),
#  ('ohohoh', 16),
#  ('someone', 16),
#  ('says', 16),
#  ('almost', 16),
#  ('line', 16),
#  ('beat', 16),
#  ('open', 16),
#  ('held', 16),
#  ('goodbye', 16),
#  ('wasnt', 16),
#  ('feels', 16),
#  ('free', 16),
#  ('own', 16),
#  ('reason', 16),
#  ('city', 16),
#  ('alive', 16),
#  ('gorgeous', 16),
#  ('cornelia', 16),
#  ('next', 15),
#  ('party', 15),
#  ('white', 15),
#  ('belong', 15),
#  ('laugh', 15),
#  ('favorite', 15),
#  ('simple', 15),
#  ('hurt', 15),
#  ('sick', 15),
#  ('heres', 15),
#  ('screaming', 15),
#  ('looked', 15),
#  ('called', 15),
#  ('sure', 15),
#  ('under', 15),
#  ('sun', 15),
#  ('tears', 15),
#  ('die', 15),
#  ('losing', 15),
#  ('running', 15),
#  ('trust', 15),
#  ('list', 15),
#  ('works', 15),
#  ('worse', 15),
#  ('fancy', 15),
#  ('happiness', 15),
#  ('plans', 15),
#  ('bless', 15),
#  ('lot', 14),
#  ('round', 14),
#  ('most', 14),
#  ('crying', 14),
#  ('comes', 14),
#  ('stupid', 14),
#  ('feet', 14),
#  ('doing', 14),
#  ('ending', 14),
#  ('doin', 14),
#  ('couldve', 14),
#  ('each', 14),
#  ('bright', 14),
#  ('taking', 14),
#  ('sing', 14),
#  ('saying', 14),
#  ('whos', 14),
#  ('worth', 14),
#  ('black', 14),
#  ('whenever', 14),
#  ('worst', 14),
#  ('treacherous', 14),
#  ('bed', 14),
#  ('does', 14),
#  ('whats', 14),
#  ('memories', 14),
#  ('anywhere', 14),
#  ('breath', 13),
#  ('wondering', 13),
#  ('wake', 13),
#  ('cry', 13),
#  ('work', 13),
#  ('watched', 13),
#  ('undone', 13),
#  ('speak', 13),
#  ('school', 13),
#  ('outside', 13),
#  ('learned', 13),
#  ('apart', 13),
#  ('rest', 13),
#  ('wouldnt', 13),
#  ('pretend', 13),
#  ('signs', 13),
#  ('golden', 13),
#  ('moved', 13),
#  ('anyone', 13),
#  ('nights', 13),
#  ('22', 13),
#  ('problems', 13),
#  ('loves', 13),
#  ('bought', 13),
#  ('drunk', 13),
#  ('december', 13),
#  ('hit', 13),
#  ('turned', 13),
#  ('sitting', 13),
#  ('behind', 13),
#  ('oohoohoohooh', 13),
#  ('boys', 12),
#  ('fifteen', 12),
#  ('sit', 12),
#  ('theyre', 12),
#  ('changed', 12),
#  ('talking', 12),
#  ('catch', 12),
#  ('step', 12),
#  ('fighting', 12),
#  ('rush', 12),
#  ('wild', 12),
#  ('low', 12),
#  ('gold', 12),
#  ('until', 12),
#  ('paint', 12),
#  ('walls', 12),
#  ('win', 12),
#  ('million', 12),
#  ('sleep', 12),
#  ('gray', 12),
#  ('takes', 12),
#  ('burned', 12),
#  ('cruel', 12),
#  ('fast', 12),
#  ('busy', 12),
#  ('fire', 12),
#  ('quite', 12),
#  ('funny', 12),
#  ('any', 12),
#  ('heartbreak', 12),
#  ('though', 12),
#  ('reputation', 12),
#  ('usin', 12),
#  ('floor', 12),
#  ('oohah', 12),
#  ('wonder', 11),
#  ('slow', 11),
#  ('havent', 11),
#  ('ends', 11),
#  ('flashback', 11),
#  ('starts', 11),
#  ('air', 11),
#  ('pulled', 11),
#  ('write', 11),
#  ('going', 11),
#  ('killing', 11),
#  ('inside', 11),
#  ('insane', 11),
#  ('seems', 11),
#  ('hide', 11),
#  ('scared', 11),
#  ('throw', 11),
#  ('hang', 11),
#  ('invisible', 11),
#  ('tryna', 11),
#  ('broke', 11),
#  ('water', 11),
#  ('daydream', 11),
#  ('blame', 11),
#  ('singing', 11),
#  ('promise', 11),
#  ('paper', 11),
#  ('lets', 11),
#  ('green', 11),
#  ('marvelous', 11),
#  ('ya', 11),
#  ('style', 11),
#  ('sign', 11),
#  ('damn', 11),
#  ('word', 11),
#  ('ready', 11),
#  ('passed', 11),
#  ('drug', 11),
#  ('woman', 11),
#  ('sparks', 11),
#  ('uh', 11),
#  ('brave', 10),
#  ('cried', 10),
#  ('hello', 10),
#  ('mess', 10),
#  ('mmmm', 10),
#  ('brought', 10),
#  ('giving', 10),
#  ('taken', 10),
#  ('figured', 10),
#  ('hearts', 10),
#  ('cuts', 10),
#  ('three', 10),
#  ('heaven', 10),
#  ('everyone', 10),
#  ('arms', 10),
#  ('strong', 10),
#  ('spinning', 10),
#  ('slope', 10),
#  ('lying', 10),
#  ('falling', 10),
#  ('scene', 10),
#  ('lord', 10),
#  ('lover', 10),
#  ('months', 10),
#  ('blind', 10),
#  ('started', 10),
#  ('wildest', 10),
#  ('ateam', 10),
#  ('whys', 10),
#  ('turns', 10),
#  ('american', 10),
#  ('wine', 10),
#  ('nobodys', 10),
#  ('forgot', 10),
#  ('worship', 10),
#  ('prove', 10),
#  ('closure', 10),
#  ('fearless', 9),
#  ('yourself', 9),
#  ('garden', 9),
#  ('afraid', 9),
#  ('faith', 9),
#  ('half', 9),
#  ('lead', 9),
#  ('small', 9),
#  ('chance', 9),
#  ('short', 9),
#  ('movie', 9),
#  ('2', 9),
#  ('heartbeat', 9),
#  ('breaking', 9),
#  ('warning', 9),
#  ('drop', 9),
#  ('move', 9),
#  ('threw', 9),
#  ('mistakes', 9),
#  ('broken', 9),
#  ('grace', 9),
#  ('fate', 9),
#  ('uhuh', 9),
#  ('swear', 9),
#  ('peace', 9),
#  ('stayed', 9),
#  ('page', 9),
#  ('understand', 9),
#  ('pouring', 9),
#  ('dressed', 9),
#  ('london', 9),
#  ('ahah', 9),
#  ('loud', 9),
#  ('rumors', 9),
#  ('less', 9),
#  ('shaking', 9),
#  ('pictures', 9),
#  ('covered', 9),
#  ('calm', 9),
#  ('shit', 9),
#  ('radidididididididididada', 9),
#  ('bar', 9),
#  ('champagne', 9),
#  ('shined', 9),
#  ('truck', 9),
#  ('drew', 9),
#  ('rings', 9),
#  ('death', 9),
#  ('evermore', 9),
#  ('storm', 8),
#  ('somewhere', 8),
#  ('quiet', 8),
#  ('letter', 8),
#  ('mmm', 8),
#  ('wear', 8),
#  ('dreaming', 8),
#  ('jeans', 8),
#  ('heels', 8),
#  ('playing', 8),
#  ('bring', 8),
#  ('tried', 8),
#  ('innocent', 8),
#  ('space', 8),
#  ('stare', 8),
#  ('bedroom', 8),
#  ('lives', 8),
#  ('wind', 8),
#  ('scream', 8),
#  ('guitar', 8),
#  ('sweet', 8),
#  ('part', 8),
#  ('such', 8),
#  ('telling', 8),
#  ('flying', 8),
#  ('solve', 8),
#  ('reckless', 8),
#  ('choice', 8),
#  ('bone', 8),
#  ('care', 8),
#  ('flew', 8),
#  ('hell', 8),
#  ('pieces', 8),
#  ('cheeks', 8),
#  ('kid', 8),
#  ('instead', 8),
#  ('sleeping', 8),
#  ('oohoohoohoohooh', 8),
#  ('fears', 8),
#  ('ohho', 8),
#  ('warm', 8),
#  ('train', 8),
#  ('queen', 8),
#  ('money', 8),
#  ('rose', 8),
#  ('tall', 8),
#  ('ones', 8),
#  ('great', 8),
#  ('keeps', 8),
#  ('flames', 8),
#  ('scar', 8),
#  ('king', 8),
#  ('leads', 8),
#  ('mmmmmm', 8),
#  ('spot', 8),
#  ('haah', 8),
#  ('strike', 8),
#  ('waters', 8),
#  ('living', 8),
#  ('haunt', 8),
#  ('film', 8),
#  ('kill', 8),
#  ('thousand', 8),
#  ('wreck', 8),
#  ('dorothea', 8),
#  ('driving', 7),
#  ('seat', 7),
#  ('team', 7),
#  ('marry', 7),
#  ('realized', 7),
#  ('prince', 7),
#  ('ring', 7),
#  ('pick', 7),
#  ('mmmmm', 7),
#  ('rocks', 7),
#  ('holding', 7),
#  ('leaving', 7),
#  ('honestly', 7),
#  ('believed', 7),
#  ('shoulda', 7),
#  ('knees', 7),
#  ('forgiveness', 7),
#  ('shell', 7),
#  ('songs', 7),
#  ('someones', 7),
#  ('hoping', 7),
#  ('cursing', 7),
#  ('talks', 7),
#  ('tight', 7),
#  ('hallelujah', 7),
#  ('faster', 7),
#  ('battle', 7),
#  ('sound', 7),
#  ('spelling', 7),
#  ('start', 7),
#  ('rules', 7),
#  ('wall', 7),
#  ('counting', 7),
#  ('conversation', 7),
#  ('faded', 7),
#  ('stairs', 7),
#  ('shouldnt', 7),
#  ('lived', 7),
#  ('wasted', 7),
#  ('freedom', 7),
#  ('hows', 7),
#  ('above', 7),
#  ('shining', 7),
#  ('iii', 7),
#  ('truth', 7),
#  ('clothes', 7),
#  ('skin', 7),
#  ('hurts', 7),
#  ('headlights', 7),
#  ('drowning', 7),
#  ('joke', 7),
#  ('somehow', 7),
#  ('ran', 7),
#  ('asked', 7),
#  ('lonely', 7),
#  ('wearing', 7),
#  ('brand', 7),
#  ('spend', 7),
#  ('lipstick', 7),
#  ('players', 7),
#  ('twenty', 7),
#  ('palm', 7),
#  ('whyd', 7),
#  ('shiny', 7),
#  ('whisper', 7),
#  ('older', 7),
#  ('haunted', 7),
#  ('lie', 7),
#  ('twice', 7),
#  ('kingdom', 7),
#  ('actress', 7),
#  ('ridin', 7),
#  ('dying', 7),
#  ('case', 7),
#  ('pay', 7),
#  ('dear', 7),
#  ('roll', 7),
#  ('glass', 7),
#  ('huh', 7),
#  ('ours', 7),
#  ('meee', 7),
#  ('colder', 7),
#  ('superman', 7),
#  ('nothin', 6),
#  ('lalala', 6),
#  ('crowd', 6),
#  ('romeo', 6),
#  ('near', 6),
#  ('reasons', 6),
#  ('forth', 6),
#  ('itll', 6),
#  ('secrets', 6),
#  ('2am', 6),
#  ('happened', 6),
#  ('second', 6),
#  ('hasnt', 6),
#  ('trees', 6),
#  ('names', 6),
#  ('ride', 6),
#  ('smiles', 6),
#  ('wide', 6),
#  ('brighter', 6),
#  ('dim', 6),
#  ('radio', 6),
#  ('comin', 6),
#  ('starin', 6),
#  ('lies', 6),
#  ('amount', 6),
#  ('casually', 6),
#  ('different', 6),
#  ('gate', 6),
#  ('saint', 6),
#  ('colors', 6),
#  ('forgetting', 6),
#  ('impossible', 6),
#  ('midnight', 6),
#  ('given', 6),
#  ('tragic', 6),
#  ('smoke', 6),
#  ('lock', 6),
#  ('strange', 6),
#  ('family', 6),
#  ('motion', 6),
#  ('seem', 6),
#  ('weekend', 6),
#  ('exlovers', 6),
#  ('skies', 6),
#  ('view', 6),
#  ('crashing', 6),
#  ('color', 6),
#  ('pushed', 6),
#  ('least', 6),
#  ('windows', 6),
#  ('hung', 6),
#  ('done', 6),
#  ('scars', 6),
#  ('standin', 6),
#  ('frames', 6),
#  ('sight', 6),
#  ('grown', 6),
#  ('castle', 6),
#  ('romantics', 6),
#  ('dada', 6),
#  ('use', 6),
#  ('cross', 6),
#  ('lovin', 6),
#  ('chill', 6),
#  ('crime', 6),
#  ('secret', 6),
#  ('frozen', 6),
#  ('shape', 6),
#  ('babys', 6),
#  ('tim', 6),
#  ('mcgraw', 6),
#  ('teardrops', 6),
#  ('shade', 6),
#  ('fore', 6),
#  ('hallway', 6),
#  ('waves', 6),
#  ('august', 6),
#  ('likes', 6),
#  ('daughter', 6),
#  ('existed', 6),
#  ('wants', 6),
#  ('1', 6),
#  ('hometown', 6),
#  ('false', 6),
#  ('goddamn', 6),
#  ('stone', 6),
#  ('enchanted', 6),
#  ('drag', 5),
#  ('flawless', 5),
#  ('thinkin', 5),
#  ('dancin', 5),
#  ('swore', 5),
#  ('bigger', 5),
#  ('supposed', 5),
#  ('princess', 5),
#  ('stephen', 5),
#  ('tossing', 5),
#  ('angel', 5),
#  ('tuesday', 5),
#  ('music', 5),
#  ('understands', 5),
#  ('streets', 5),
#  ('none', 5),
#  ('minds', 5),
#  ('tragedy', 5),
#  ('swing', 5),
#  ('attitude', 5),
#  ('hadnt', 5),
#  ('listen', 5),
#  ('father', 5),
#  ('snow', 5),
#  ('grab', 5),
#  ('keys', 5),
#  ('grew', 5),
#  ('ships', 5),
#  ('daddys', 5),
#  ('watching', 5),
#  ('realize', 5),
#  ('waking', 5),
#  ('note', 5),
#  ('played', 5),
#  ('spotlight', 5),
#  ('desperately', 5),
#  ('superstar', 5),
#  ('sayin', 5),
#  ('pride', 5),
#  ('slamming', 5),
#  ('picked', 5),
#  ('wore', 5),
#  ('sense', 5),
#  ('reminds', 5),
#  ('pocket', 5),
#  ('child', 5),
#  ('meant', 5),
#  ('breakin', 5),
#  ('misery', 5),
#  ('porch', 5),
#  ('recall', 5),
#  ('neck', 5),
#  ('sunny', 5),
#  ('mm', 5),
#  ('woke', 5),
#  ('learn', 5),
#  ('state', 5),
#  ('unless', 5),
#  ('autumn', 5),
#  ('path', 5),
#  ('voice', 5),
#  ...]

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
#    She mostly talks about you and then herself, while that's not surprising, it also tells us that she's mostly writing about relationships and her realtionships with others.
# </details>

# %% [markdown]
# ### 11. Analyze Lyric Sentiment
#
# To better understand how she thinks and feels about day and night, we want to know which one she writes about more favorably.
#
# We are going to use the pre-trained sentiment classifier that comes with NLTK. It's it trained on tweets and therefore best for short text. It return 4 values: positive, negative, neutral, and compound. Compound will be of special interest to us. It is the normalized sum of positive and negative.
#
# * Run the sample sentiment analyzer cell to see how the SentimentIntensityAnalyzer works.
# * Apply the sia sentiment analyzer to the clean_lyric column of the DataFrame with a lambda expression
# * Run the cell that transforms the dictionary into columns of the DataFrame

# %%
#run this cell to add a package from NLTK for our sentiment analyzer.
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/ccuser/nltk_data...
# True

# %%
#run this cell to see how the sentiment analyzer works
sia = SentimentIntensityAnalyzer()
sia.polarity_scores("I love Taylor Swift")
# Out:
# {'neg': 0.0, 'neu': 0.143, 'pos': 0.857, 'compound': 0.7184}

# %%
#create a new column called polarity and apply the sia method to the clean_lyric column with a lambda expression
## YOUR CODE HERE ##
lyrics['polarity'] = lyrics['clean_lyric'].apply(lambda x: sia.polarity_scores(x))
lyrics.head()
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line album_year  \
# 0                    There's something 'bout the way     1       2008
# 1             The street looks when it's just rained     2       2008
# 2  There's a glow off the pavement, you walk me t...     3       2008
# 3  And you know I wanna ask you to dance right there     4       2008
# 4             In the middle of the parking lot, yeah     5       2008
#
#                                     clean_lyric  midnight  night_words  \
# 0                     theres something bout way     False        False
# 1             street looks when its just rained     False        False
# 2         theres glow off pavement you walk car     False        False
# 3  and you know wanna ask you dance right there     False        False
# 4                 in middle of parking lot yeah     False        False
#
#    day_words  time_words  position  \
# 0      False       False     1.001
# 1      False       False     1.002
# 2      False       False     1.003
# 3      False       False     1.004
# 4      False       False     1.005
#
#                                           lyrics_tok  \
# 0                     [theres, something, bout, way]
# 1           [street, looks, when, its, just, rained]
# 2      [theres, glow, off, pavement, you, walk, car]
# 3  [and, you, know, wan, na, ask, you, dance, rig...
# 4               [in, middle, of, parking, lot, yeah]
#
#                                             polarity
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.0, 'neu': 0.694, 'pos': 0.306, 'comp...

# %%
#run this cell to transform the polarity dictionary into columns of the DataFrame
lyrics[['neg', 'neu', 'pos', 'compound']] = lyrics['polarity'].apply(pd.Series)
lyrics = lyrics.drop('polarity', axis=1)

# %%
#inspect the first few rows
## YOUR CODE HERE ##
lyrics.head()
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line album_year  \
# 0                    There's something 'bout the way     1       2008
# 1             The street looks when it's just rained     2       2008
# 2  There's a glow off the pavement, you walk me t...     3       2008
# 3  And you know I wanna ask you to dance right there     4       2008
# 4             In the middle of the parking lot, yeah     5       2008
#
#                                     clean_lyric  midnight  night_words  \
# 0                     theres something bout way     False        False
# 1             street looks when its just rained     False        False
# 2         theres glow off pavement you walk car     False        False
# 3  and you know wanna ask you dance right there     False        False
# 4                 in middle of parking lot yeah     False        False
#
#    day_words  time_words  position  \
# 0      False       False     1.001
# 1      False       False     1.002
# 2      False       False     1.003
# 3      False       False     1.004
# 4      False       False     1.005
#
#                                           lyrics_tok  neg    neu    pos  \
# 0                     [theres, something, bout, way]  0.0  1.000  0.000
# 1           [street, looks, when, its, just, rained]  0.0  1.000  0.000
# 2      [theres, glow, off, pavement, you, walk, car]  0.0  1.000  0.000
# 3  [and, you, know, wan, na, ask, you, dance, rig...  0.0  1.000  0.000
# 4               [in, middle, of, parking, lot, yeah]  0.0  0.694  0.306
#
#    compound
# 0     0.000
# 1     0.000
# 2     0.000
# 3     0.000
# 4     0.296

# %% [markdown]
# ### 12. Corpus Sentiment Analysis
#
# Now that we have sentiment for all of her lyrics, let's learn more about her overall sentiment, as well as how that has change throughout her career.
# * Use the pos, neg, and compound columns to calculate the overall sentiment of her entire collection, and print the result.
# * Use the groupby function and matplotlib to visualize the overall sentiment of her albums over time

# %%
#calculate overall sentiment for pos, neg, sentiment
## YOUR CODE HERE ##
pos = sum(lyrics['pos'])
neg = sum(lyrics['neg'])
compound = sum(lyrics['compound'])

#print the overall sentiments
## YOUR CODE HERE ##
print(pos, neg, compound)
# Out:
# 1131.2680000000028 736.1600000000004 428.61660000000086

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
#    Overall Taylor Swift's lyrics are mostly positive!
# </details>

# %%
#create a new DataFrame using the groupby method for the album_year
## YOUR CODE HERE ##
yearly_sentiment = lyrics.groupby('album_year').sum().reset_index()
yearly_sentiment

#visualize sentiment over time 
## YOUR CODE HERE ##
plt.plot(yearly_sentiment['album_year'], yearly_sentiment['compound'])
plt.show()

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
#    Her degree of positivity has really fluctuated over time. Her 2020 album was by far the least positive, though all of her albums are actually positive.
# </details>

# %% [markdown]
# ### 13. Day or Night? Positive or Negative
# Finally the big reveal. Does Taylor Swift write more positively about day or night?
# * Create two DataFrames: one for all the lyrics that mention night and one for all the lyrics that mention day.
# * Check that each DataFrame has the right number of values with the `len()` function
# * Calculate the sentiment for both night and day using the compound value and print them.

# %%
#create a DataFrame filtered for only night mentions
## YOUR CODE HERE ##
night_mentions = lyrics[lyrics['night_words'] == True]
#create a DataFrame filtered for only day mentions
## YOUR CODE HERE ##
day_mentions = lyrics[lyrics['day_words'] == True]
#print the length of the night and day DataFrames
## YOUR CODE HERE ##
print(f' night: {len(night_mentions)} day: {len(day_mentions)}')
# Out:
#  night: 245 day: 363

# %%
#calculate the sentiment of each day and night DataFrame from the compound values
## YOUR CODE HERE ##
sentiment_night = night_mentions['compound'].sum()
sentiment_day = day_mentions['compound'].sum()
#print the results
## YOUR CODE HERE ##
print(f' night: {sentiment_night} day: {sentiment_day}')
# Out:
#  night: 17.4022 day: 25.416800000000002

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# She's still overall more positive in her sentiment about day than night!
#
# You have the tools to explore if that sentiment has changed over time, or if her feelings towards night have grown more positive or negative over time. And of course, we would love to see your analysis of her new album, Midnight. Have her feelings changed?
#
# Share your findings in the Codecademy forums!
# </details>
